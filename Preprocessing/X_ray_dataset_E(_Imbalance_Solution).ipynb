# %% [markdown]
# # 데이터 준비

# %%
# 라벨 1,12만 들어있는 이미지
# !gdown https://drive.google.com/uc?id=1BG8TXbpOddVEeLW7evRnW9N4H94U3B1P
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BG8TXbpOddVEeLW7evRnW9N4H94U3B1P
# To: /content/id_1_12_image_label.zip
# 100% 39.1M/39.1M [00:00<00:00, 145MB/s]

# %%
# !unzip id_1_12_image_label.zip

# %%
# !rm /content/id_1_12_image_label.zip

# %%
pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-876bcdf0-366d-442c-98a8-0ae56ef1e0ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-876bcdf0-366d-442c-98a8-0ae56ef1e0ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"bbonghag","key":"8cb192135a4913f47ffb76f5565864e2"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !mkdir yolo_labels
# !kaggle datasets download -d awsaf49/vinbigdata-yolo-labels-dataset
# Out:
# Downloading vinbigdata-yolo-labels-dataset.zip to /content
# 100% 4.85M/4.85M [00:00<00:00, 21.3MB/s]
# 100% 4.85M/4.85M [00:00<00:00, 21.3MB/s]

# %%
# !kaggle datasets download -d awsaf49/vinbigdata-512-image-dataset
# Out:
# Downloading vinbigdata-512-image-dataset.zip to /content
# 100% 2.29G/2.30G [00:57<00:00, 49.0MB/s]
# 100% 2.30G/2.30G [00:57<00:00, 42.8MB/s]

# %%
# !unzip -d /content/yolo_labels /content/vinbigdata-yolo-labels-dataset.zip

# %%
# !unzip /content/vinbigdata-512-image-dataset.zip

# %%
# !rm /content/vinbigdata-512-image-dataset.zip
# !rm /content/vinbigdata-yolo-labels-dataset.zip

# %%
# !pip install albumentations==0.4.6
import albumentations 
from albumentations.pytorch import ToTensorV2

# %%
import pandas as pd
import numpy as np
import cv2
import os
import re
import time
import json
import os
import glob
from PIL import Image

import imgaug.augmenters as iaa
from sklearn.model_selection import GroupKFold

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import torch
import torchvision

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN

from torch.utils.data import DataLoader, Dataset

from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
train_dir = '/content/vinbigdata/train'
test_dir = '/content/vinbigdata/test'
train_df = pd.read_csv('/content/vinbigdata/train.csv')
test_df = pd.read_csv('/content/vinbigdata/test.csv')

# %%
# id = 14 : no finding, 정상 이미지므로 제외.
train_df = train_df[train_df['class_id'] != 14].reset_index(drop=True)
train_df['image_path'] = '/content/vinbigdata/train/'+train_df.image_id+'.png'

# %%
IMG_SIZE = 512
train_df['xmin'] = ((train_df['x_min']/train_df['width'])*IMG_SIZE).astype('int')
train_df['ymin'] = ((train_df['y_min']/train_df['height'])*IMG_SIZE).astype('int')
train_df['xmax'] = ((train_df['x_max']/train_df['width'])*IMG_SIZE).astype('int')
train_df['ymax'] = ((train_df['y_max']/train_df['height'])*IMG_SIZE).astype('int')

# train_df['xmin'] = (train_df['x_min']/train_df['width'])*IMG_SIZE
# train_df['ymin'] = (train_df['y_min']/train_df['height'])*IMG_SIZE
# train_df['xmax'] = (train_df['x_max']/train_df['width'])*IMG_SIZE
# train_df['ymax'] = (train_df['y_max']/train_df['height'])*IMG_SIZE

train_df['x_mid'] = ((train_df['xmax']+train_df['xmin'])/2)/IMG_SIZE 
train_df['y_mid'] = ((train_df['ymax']+train_df['ymin'])/2)/IMG_SIZE 
train_df['w'] = (train_df['xmax'] - train_df['xmin'])/IMG_SIZE 
train_df['h'] = (train_df['ymax'] - train_df['ymin'])/IMG_SIZE

# %%
len(os.listdir('/content/image_id1')) +len(os.listdir('/content/image_id12'))
# Out:
# 282

# %% [markdown]
# 1번 이미지 : 186장
#
# 12번 이미지 : 96장
#
# 총 282장

# %% [markdown]
# # Task1. 데이터 다운샘플링

# %%
# 라벨 빈도수 시각화 
df = train_df[['image_id', 'class_id']]
count_df = pd.DataFrame(df.class_id.value_counts()) # 평균값은 2578
count_df.plot.bar(figsize=(10,5), rot=0)

# %%
# 제일 많은 데이터 4개 라벨을 선정 후 다운샘플링하는 코드.
over_list = [0,3,11,13]
for i in over_list:
    id_df = train_df[train_df.class_id == i]
    uni_id = id_df.image_id.unique().tolist() # 라벨이 i인 이미지 파일 이름 리스트 
    for id in uni_id:
        if id_df.image_id.value_counts()[id] > 2: # 빈도수가 2를 넘는 파일이름들을 가져와서 
            id_list = id_df[id_df.image_id == id].index.tolist()[:2]  # 2개씩 자르고 나머지는 남기고 데이터프레임에서 삭제.
            id_df.drop(index=id_list, axis=0, inplace=True)
            if i == 0:
                id_0 = id_df
            elif i == 3:
                id_3 = id_df
            elif i == 11:
                id_11 = id_df
            else:
                id_13 = id_df

reduced_df = pd.concat([id_0, id_3, id_11, id_13], axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
reduced_df
# Out:
#                                image_id          class_name  class_id rad_id  \
# 5      d3637a1935a905b3c326af31389cb846  Aortic enlargement         0    R10
# 9      321c111713c3ee5385db0effb54ff568  Aortic enlargement         0     R8
# 12     fb8e11c6b2886b2d41b379e0598669b9  Aortic enlargement         0    R10
# 70     51a8d7259a0a6deac20b7c4979a7e847  Aortic enlargement         0    R14
# 96     381e9c224c892d437f498779e349469e  Aortic enlargement         0    R10
# ...                                 ...                 ...       ...    ...
# 36043  a99a720cab88405baaf789e85ce20c45  Pulmonary fibrosis        13     R9
# 36062  b6bb5088976d0d3d51f3041b2172cffb  Pulmonary fibrosis        13     R9
# 36064  93ed73782bc23a0ef9c426c21982d8d7  Pulmonary fibrosis        13     R8
# 36077  cc47c14b9aa97e08fad1925a6dc1efee  Pulmonary fibrosis        13     R9
# 36092  26d1d5a0ef2e692c6340e74859ffdc53  Pulmonary fibrosis        13    R10
#
#         x_min   y_min   x_max   y_max  width  height  \
# 5      1329.0   743.0  1521.0   958.0   2304    2880
# 9      1292.0   554.0  1477.0   805.0   2304    2880
# 12     1390.0   878.0  1616.0  1163.0   2304    2880
# 70      841.0   510.0  1446.0   888.0   2174    2234
# 96     1481.0   875.0  1674.0  1097.0   2571    2666
# ...       ...     ...     ...     ...    ...     ...
# 36043   526.0   569.0   931.0  1133.0   2304    2880
# 36062   510.0   554.0   999.0  1108.0   2544    2828
# 36064  1838.0  1258.0  2225.0  1419.0   2613    3005
# 36077   643.0   726.0  1202.0  1251.0   2753    2776
# 36092  1163.0   787.0  1338.0   941.0   3072    3072
#
#                                               image_path  xmin  ymin  xmax  \
# 5      /content/vinbigdata/train/d3637a1935a905b3c326...   295   132   338
# 9      /content/vinbigdata/train/321c111713c3ee5385db...   287    98   328
# 12     /content/vinbigdata/train/fb8e11c6b2886b2d41b3...   308   156   359
# 70     /content/vinbigdata/train/51a8d7259a0a6deac20b...   198   116   340
# 96     /content/vinbigdata/train/381e9c224c892d437f49...   294   168   333
# ...                                                  ...   ...   ...   ...
# 36043  /content/vinbigdata/train/a99a720cab88405baaf7...   116   101   206
# 36062  /content/vinbigdata/train/b6bb5088976d0d3d51f3...   102   100   201
# 36064  /content/vinbigdata/train/93ed73782bc23a0ef9c4...   360   214   435
# 36077  /content/vinbigdata/train/cc47c14b9aa97e08fad1...   119   133   223
# 36092  /content/vinbigdata/train/26d1d5a0ef2e692c6340...   193   131   223
#
#        ymax     x_mid     y_mid         w         h
# 5       170  0.618164  0.294922  0.083984  0.074219
# 9       143  0.600586  0.235352  0.080078  0.087891
# 12      206  0.651367  0.353516  0.099609  0.097656
# 70      203  0.525391  0.311523  0.277344  0.169922
# 96      210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 36043   201  0.314453  0.294922  0.175781  0.195312
# 36062   200  0.295898  0.292969  0.193359  0.195312
# 36064   241  0.776367  0.444336  0.146484  0.052734
# 36077   230  0.333984  0.354492  0.203125  0.189453
# 36092   156  0.406250  0.280273  0.058594  0.048828
#
# [13012 rows x 19 columns]

# %%
# 라벨 0, 3, 11, 13 번 제외.
train_df1 = train_df[(train_df.class_id != 0) & (train_df.class_id != 3) & (train_df.class_id != 11) & (train_df.class_id != 13)]
train_df1
# Out:
#                                image_id        class_name  class_id rad_id  \
# 3      0c7a38f293d5f5e4846aa4ca6db4daf1               ILD         5    R17
# 4      47ed17dcb2cbeec15182ed335a8b5a9e       Nodule/Mass         8     R9
# 7      7c1add6833d5f0102b0d3619a1682a64      Lung Opacity         7    R10
# 10     80caa435b6ab5edaff4a0a758ffaec6e       Atelectasis         1     R9
# 16     c394eadea89e5795c8037280492d116d      Other lesion         9     R9
# ...                                 ...               ...       ...    ...
# 36088  66332eb5425bcdc6854aae970cc656b9       Nodule/Mass         8     R8
# 36090  3b887c0550e9722c9b86b7c22ad09e11      Other lesion         9    R10
# 36091  b53d1dd80e99ca6bcef9d592f65d3321  Pleural effusion        10     R9
# 36093  22672ab82c290c20b86863291e25ef6c               ILD         5     R9
# 36094  db169d0be36123bd55b866d6aa73983b      Other lesion         9     R8
#
#         x_min   y_min   x_max   y_max  width  height  \
# 3      1347.0   245.0  2188.0  2169.0   2285    2555
# 4       557.0  2352.0   675.0  2484.0   2568    3353
# 7       600.0  1332.0   903.0  1523.0   2944    3014
# 10      331.0   462.0  1384.0  2365.0   3001    3107
# 16        0.0   839.0   274.0  2168.0   2304    2880
# ...       ...     ...     ...     ...    ...     ...
# 36088  2161.0  1600.0  2308.0  1758.0   2936    2963
# 36090   254.0  1959.0   280.0  1990.0   2630    3073
# 36091   240.0  1550.0   562.0  2001.0   2304    2880
# 36093   299.0   664.0   794.0  1508.0   2048    2500
# 36094     6.0   670.0   272.0  1736.0   2304    2880
#
#                                               image_path  xmin  ymin  xmax  \
# 3      /content/vinbigdata/train/0c7a38f293d5f5e4846a...   301    49   490
# 4      /content/vinbigdata/train/47ed17dcb2cbeec15182...   111   359   134
# 7      /content/vinbigdata/train/7c1add6833d5f0102b0d...   104   226   157
# 10     /content/vinbigdata/train/80caa435b6ab5edaff4a...    56    76   236
# 16     /content/vinbigdata/train/c394eadea89e5795c803...     0   149    60
# ...                                                  ...   ...   ...   ...
# 36088  /content/vinbigdata/train/66332eb5425bcdc6854a...   376   276   402
# 36090  /content/vinbigdata/train/3b887c0550e9722c9b86...    49   326    54
# 36091  /content/vinbigdata/train/b53d1dd80e99ca6bcef9...    53   275   124
# 36093  /content/vinbigdata/train/22672ab82c290c20b868...    74   135   198
# 36094  /content/vinbigdata/train/db169d0be36123bd55b8...     1   119    60
#
#        ymax     x_mid     y_mid         w         h
# 3       434  0.772461  0.471680  0.369141  0.751953
# 4       379  0.239258  0.720703  0.044922  0.039062
# 7       258  0.254883  0.472656  0.103516  0.062500
# 10      389  0.285156  0.454102  0.351562  0.611328
# 16      385  0.058594  0.521484  0.117188  0.460938
# ...     ...       ...       ...       ...       ...
# 36088   303  0.759766  0.565430  0.050781  0.052734
# 36090   331  0.100586  0.641602  0.009766  0.009766
# 36091   355  0.172852  0.615234  0.138672  0.156250
# 36093   308  0.265625  0.432617  0.242188  0.337891
# 36094   308  0.059570  0.416992  0.115234  0.369141
#
# [14010 rows x 19 columns]

# %%
total_df = pd.concat([reduced_df, train_df1], axis=0).reset_index().drop('index', axis=1)
total_df
# Out:
#                                image_id          class_name  class_id rad_id  \
# 0      d3637a1935a905b3c326af31389cb846  Aortic enlargement         0    R10
# 1      321c111713c3ee5385db0effb54ff568  Aortic enlargement         0     R8
# 2      fb8e11c6b2886b2d41b379e0598669b9  Aortic enlargement         0    R10
# 3      51a8d7259a0a6deac20b7c4979a7e847  Aortic enlargement         0    R14
# 4      381e9c224c892d437f498779e349469e  Aortic enlargement         0    R10
# ...                                 ...                 ...       ...    ...
# 27017  66332eb5425bcdc6854aae970cc656b9         Nodule/Mass         8     R8
# 27018  3b887c0550e9722c9b86b7c22ad09e11        Other lesion         9    R10
# 27019  b53d1dd80e99ca6bcef9d592f65d3321    Pleural effusion        10     R9
# 27020  22672ab82c290c20b86863291e25ef6c                 ILD         5     R9
# 27021  db169d0be36123bd55b866d6aa73983b        Other lesion         9     R8
#
#         x_min   y_min   x_max   y_max  width  height  \
# 0      1329.0   743.0  1521.0   958.0   2304    2880
# 1      1292.0   554.0  1477.0   805.0   2304    2880
# 2      1390.0   878.0  1616.0  1163.0   2304    2880
# 3       841.0   510.0  1446.0   888.0   2174    2234
# 4      1481.0   875.0  1674.0  1097.0   2571    2666
# ...       ...     ...     ...     ...    ...     ...
# 27017  2161.0  1600.0  2308.0  1758.0   2936    2963
# 27018   254.0  1959.0   280.0  1990.0   2630    3073
# 27019   240.0  1550.0   562.0  2001.0   2304    2880
# 27020   299.0   664.0   794.0  1508.0   2048    2500
# 27021     6.0   670.0   272.0  1736.0   2304    2880
#
#                                               image_path  xmin  ymin  xmax  \
# 0      /content/vinbigdata/train/d3637a1935a905b3c326...   295   132   338
# 1      /content/vinbigdata/train/321c111713c3ee5385db...   287    98   328
# 2      /content/vinbigdata/train/fb8e11c6b2886b2d41b3...   308   156   359
# 3      /content/vinbigdata/train/51a8d7259a0a6deac20b...   198   116   340
# 4      /content/vinbigdata/train/381e9c224c892d437f49...   294   168   333
# ...                                                  ...   ...   ...   ...
# 27017  /content/vinbigdata/train/66332eb5425bcdc6854a...   376   276   402
# 27018  /content/vinbigdata/train/3b887c0550e9722c9b86...    49   326    54
# 27019  /content/vinbigdata/train/b53d1dd80e99ca6bcef9...    53   275   124
# 27020  /content/vinbigdata/train/22672ab82c290c20b868...    74   135   198
# 27021  /content/vinbigdata/train/db169d0be36123bd55b8...     1   119    60
#
#        ymax     x_mid     y_mid         w         h
# 0       170  0.618164  0.294922  0.083984  0.074219
# 1       143  0.600586  0.235352  0.080078  0.087891
# 2       206  0.651367  0.353516  0.099609  0.097656
# 3       203  0.525391  0.311523  0.277344  0.169922
# 4       210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 27017   303  0.759766  0.565430  0.050781  0.052734
# 27018   331  0.100586  0.641602  0.009766  0.009766
# 27019   355  0.172852  0.615234  0.138672  0.156250
# 27020   308  0.265625  0.432617  0.242188  0.337891
# 27021   308  0.059570  0.416992  0.115234  0.369141
#
# [27022 rows x 19 columns]

# %%
total_df = total_df[['image_id', 'class_id', 'xmin', 'ymin', 'xmax', 'ymax', 'x_mid', 'y_mid', 'w', 'h']]
total_df
# Out:
#                                image_id  class_id  xmin  ymin  xmax  ymax  \
# 0      d3637a1935a905b3c326af31389cb846         0   295   132   338   170
# 1      321c111713c3ee5385db0effb54ff568         0   287    98   328   143
# 2      fb8e11c6b2886b2d41b379e0598669b9         0   308   156   359   206
# 3      51a8d7259a0a6deac20b7c4979a7e847         0   198   116   340   203
# 4      381e9c224c892d437f498779e349469e         0   294   168   333   210
# ...                                 ...       ...   ...   ...   ...   ...
# 27017  66332eb5425bcdc6854aae970cc656b9         8   376   276   402   303
# 27018  3b887c0550e9722c9b86b7c22ad09e11         9    49   326    54   331
# 27019  b53d1dd80e99ca6bcef9d592f65d3321        10    53   275   124   355
# 27020  22672ab82c290c20b86863291e25ef6c         5    74   135   198   308
# 27021  db169d0be36123bd55b866d6aa73983b         9     1   119    60   308
#
#           x_mid     y_mid         w         h
# 0      0.618164  0.294922  0.083984  0.074219
# 1      0.600586  0.235352  0.080078  0.087891
# 2      0.651367  0.353516  0.099609  0.097656
# 3      0.525391  0.311523  0.277344  0.169922
# 4      0.612305  0.369141  0.076172  0.082031
# ...         ...       ...       ...       ...
# 27017  0.759766  0.565430  0.050781  0.052734
# 27018  0.100586  0.641602  0.009766  0.009766
# 27019  0.172852  0.615234  0.138672  0.156250
# 27020  0.265625  0.432617  0.242188  0.337891
# 27021  0.059570  0.416992  0.115234  0.369141
#
# [27022 rows x 10 columns]

# %%
count1_df = pd.DataFrame(total_df.class_id.value_counts())
count1_df.plot.bar(figsize=(10,5), rot=0)

# %% [markdown]
# 과하게 높던 상위 4개 라벨들을 평균값과의 차이를 많이 줄임

# %%
total_df.class_id.value_counts()
# Out:
# 0     3672
# 11    3464
# 13    3047
# 3     2829
# 8     2580
# 7     2483
# 10    2476
# 9     2203
# 6     1247
# 5     1000
# 2      960
# 4      556
# 1      279
# 12     226
# Name: class_id, dtype: int64

# %% [markdown]
# # Task2. 이미지 증강

# %% [markdown]
# ## 1. clahe & equ image

# %%
# %mv /content/image_id12/* /content/image_id1/ 
# !rm -r /content/image_id12

# %%
len(os.listdir('/content/image_id1'))
# Out:
# 266

# %%
# 1,12번 이미지 경로 리스트 
input_path = "/content/image_id1/*.png"
image_list = [f for f in glob.glob(input_path)]

# %%
# !mkdir /content/aug_image

# %%
# clahe image 생성 함수
def clahe_image(image_list):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    for path in image_list:
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        clahe_img = clahe.apply(img)
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f'/content/aug_image/{img_name}'+'_clahe.png', clahe_img)

# %%
# equalizeHist image 만들기 

def equ_image(image_list):
    for path in image_list:
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        equ_img = cv2.equalizeHist(img)
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f'/content/aug_image/{img_name}'+'_equ.png', equ_img)

equ_image(image_list)

# %%
# 1,12번 이미지 데이터프레임. 여기 image_id에 증강한 이미지 이름이랑 맞게 바꿔서 total_df에 추가해주면 된다.
# image_id 뒤에 _clahe, _equ 추가하기.
less_df = total_df[(total_df.class_id == 1) | (total_df.class_id == 12) ]
less_df
# Out:
#                                image_id  class_id  xmin  ymin  xmax  ymax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e         1    56    76   236   389
# 13055  6e4391555899c8474c4d32f42b2ba21b        12   328    93   402   166
# 13066  8098d1ce056318c03a3c70ccf3707945         1   235   105   350   151
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3        12    59   260   242   340
# 13098  fb31baa6cb3084cb283c11ee81c32f22         1   373    88   421   133
# ...                                 ...       ...   ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6         1   286    69   349   144
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec         1   301   105   376   269
# 26896  2583527ca7c4a6e278fb4506ba8637ab        12    77   299   198   366
# 26943  4e3a3b03cf00a9060ac139f57843a241        12   306    68   414   156
# 26988  75692666e09ea0a3cbfcc4b36241c7c0        12   289    50   428   395
#
#           x_mid     y_mid         w         h
# 13015  0.285156  0.454102  0.351562  0.611328
# 13055  0.712891  0.252930  0.144531  0.142578
# 13066  0.571289  0.250000  0.224609  0.089844
# 13074  0.293945  0.585938  0.357422  0.156250
# 13098  0.775391  0.215820  0.093750  0.087891
# ...         ...       ...       ...       ...
# 26853  0.620117  0.208008  0.123047  0.146484
# 26888  0.661133  0.365234  0.146484  0.320312
# 26896  0.268555  0.649414  0.236328  0.130859
# 26943  0.703125  0.218750  0.210938  0.171875
# 26988  0.700195  0.434570  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
equ_df = less_df.copy()
equ_df['image_id'] = equ_df['image_id'] + '_equ'
equ_df
# Out:
#                                    image_id  class_id  xmin  ymin  xmax  ymax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_equ         1    56    76   236   389
# 13055  6e4391555899c8474c4d32f42b2ba21b_equ        12   328    93   402   166
# 13066  8098d1ce056318c03a3c70ccf3707945_equ         1   235   105   350   151
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_equ        12    59   260   242   340
# 13098  fb31baa6cb3084cb283c11ee81c32f22_equ         1   373    88   421   133
# ...                                     ...       ...   ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_equ         1   286    69   349   144
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_equ         1   301   105   376   269
# 26896  2583527ca7c4a6e278fb4506ba8637ab_equ        12    77   299   198   366
# 26943  4e3a3b03cf00a9060ac139f57843a241_equ        12   306    68   414   156
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_equ        12   289    50   428   395
#
#           x_mid     y_mid         w         h
# 13015  0.285156  0.454102  0.351562  0.611328
# 13055  0.712891  0.252930  0.144531  0.142578
# 13066  0.571289  0.250000  0.224609  0.089844
# 13074  0.293945  0.585938  0.357422  0.156250
# 13098  0.775391  0.215820  0.093750  0.087891
# ...         ...       ...       ...       ...
# 26853  0.620117  0.208008  0.123047  0.146484
# 26888  0.661133  0.365234  0.146484  0.320312
# 26896  0.268555  0.649414  0.236328  0.130859
# 26943  0.703125  0.218750  0.210938  0.171875
# 26988  0.700195  0.434570  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
clahe_df = less_df.copy()
clahe_df['image_id'] = clahe_df['image_id'] + '_clahe'
clahe_df
# Out:
#                                      image_id  class_id  xmin  ymin  xmax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_clahe         1    56    76   236
# 13055  6e4391555899c8474c4d32f42b2ba21b_clahe        12   328    93   402
# 13066  8098d1ce056318c03a3c70ccf3707945_clahe         1   235   105   350
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_clahe        12    59   260   242
# 13098  fb31baa6cb3084cb283c11ee81c32f22_clahe         1   373    88   421
# ...                                       ...       ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_clahe         1   286    69   349
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_clahe         1   301   105   376
# 26896  2583527ca7c4a6e278fb4506ba8637ab_clahe        12    77   299   198
# 26943  4e3a3b03cf00a9060ac139f57843a241_clahe        12   306    68   414
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_clahe        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 13015   389  0.285156  0.454102  0.351562  0.611328
# 13055   166  0.712891  0.252930  0.144531  0.142578
# 13066   151  0.571289  0.250000  0.224609  0.089844
# 13074   340  0.293945  0.585938  0.357422  0.156250
# 13098   133  0.775391  0.215820  0.093750  0.087891
# ...     ...       ...       ...       ...       ...
# 26853   144  0.620117  0.208008  0.123047  0.146484
# 26888   269  0.661133  0.365234  0.146484  0.320312
# 26896   366  0.268555  0.649414  0.236328  0.130859
# 26943   156  0.703125  0.218750  0.210938  0.171875
# 26988   395  0.700195  0.434570  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
# 원본 이미지 + 1,12번 equ + 1,12번 clahe
aug_df = pd.concat([total_df, equ_df, clahe_df], axis=0).reset_index().drop('index', axis=1)
aug_df
# Out:
#                                      image_id  class_id  xmin  ymin  xmax  \
# 0            d3637a1935a905b3c326af31389cb846         0   295   132   338
# 1            321c111713c3ee5385db0effb54ff568         0   287    98   328
# 2            fb8e11c6b2886b2d41b379e0598669b9         0   308   156   359
# 3            51a8d7259a0a6deac20b7c4979a7e847         0   198   116   340
# 4            381e9c224c892d437f498779e349469e         0   294   168   333
# ...                                       ...       ...   ...   ...   ...
# 28027  0abd4fc2425edd5c2efb2c149e9319c6_clahe         1   286    69   349
# 28028  2f4573aa154b6ee5f4ba4dc90626f5ec_clahe         1   301   105   376
# 28029  2583527ca7c4a6e278fb4506ba8637ab_clahe        12    77   299   198
# 28030  4e3a3b03cf00a9060ac139f57843a241_clahe        12   306    68   414
# 28031  75692666e09ea0a3cbfcc4b36241c7c0_clahe        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 0       170  0.618164  0.294922  0.083984  0.074219
# 1       143  0.600586  0.235352  0.080078  0.087891
# 2       206  0.651367  0.353516  0.099609  0.097656
# 3       203  0.525391  0.311523  0.277344  0.169922
# 4       210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 28027   144  0.620117  0.208008  0.123047  0.146484
# 28028   269  0.661133  0.365234  0.146484  0.320312
# 28029   366  0.268555  0.649414  0.236328  0.130859
# 28030   156  0.703125  0.218750  0.210938  0.171875
# 28031   395  0.700195  0.434570  0.271484  0.673828
#
# [28032 rows x 10 columns]

# %% [markdown]
# ## 2. flip image

# %%
def flip_image(image_list):
    for path in image_list:
        img = cv2.imread(path)
        flipped_img = cv2.flip(img, 1) 
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f'/content/aug_image/{img_name}'+'_flip.png', flipped_img)

flip_image(image_list)

# %% [markdown]
#  플립된 이미지의 x_mid, y_mid 구해서 추가 / flip bbox 계산 : (256-x_min,y_min), (256-x_max,y_max)
#
#  플립시 바운딩박스의 x좌표가 변하므로 바뀐 좌표로 바꿔줘야 한다.

# %%
flip_df = less_df.copy()
flip_df['x_mid'] = (((512 - flip_df['xmin'])+(512 - flip_df['xmax']))//2)/512
flip_df['y_mid'] = ((flip_df['ymin'] + flip_df['ymax'])//2)/512
flip_df['image_id'] = flip_df['image_id'] + '_flip'
flip_df
# Out:
#                                     image_id  class_id  xmin  ymin  xmax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_flip         1    56    76   236
# 13055  6e4391555899c8474c4d32f42b2ba21b_flip        12   328    93   402
# 13066  8098d1ce056318c03a3c70ccf3707945_flip         1   235   105   350
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_flip        12    59   260   242
# 13098  fb31baa6cb3084cb283c11ee81c32f22_flip         1   373    88   421
# ...                                      ...       ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_flip         1   286    69   349
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_flip         1   301   105   376
# 26896  2583527ca7c4a6e278fb4506ba8637ab_flip        12    77   299   198
# 26943  4e3a3b03cf00a9060ac139f57843a241_flip        12   306    68   414
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_flip        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 13015   389  0.714844  0.453125  0.351562  0.611328
# 13055   166  0.287109  0.251953  0.144531  0.142578
# 13066   151  0.427734  0.250000  0.224609  0.089844
# 13074   340  0.705078  0.585938  0.357422  0.156250
# 13098   133  0.224609  0.214844  0.093750  0.087891
# ...     ...       ...       ...       ...       ...
# 26853   144  0.378906  0.207031  0.123047  0.146484
# 26888   269  0.337891  0.365234  0.146484  0.320312
# 26896   366  0.730469  0.648438  0.236328  0.130859
# 26943   156  0.296875  0.218750  0.210938  0.171875
# 26988   395  0.298828  0.433594  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
aug_df = pd.concat([total_df, equ_df, clahe_df, flip_df], axis=0).reset_index().drop('index', axis=1)
aug_df
# Out:
#                                     image_id  class_id  xmin  ymin  xmax  \
# 0           d3637a1935a905b3c326af31389cb846         0   295   132   338
# 1           321c111713c3ee5385db0effb54ff568         0   287    98   328
# 2           fb8e11c6b2886b2d41b379e0598669b9         0   308   156   359
# 3           51a8d7259a0a6deac20b7c4979a7e847         0   198   116   340
# 4           381e9c224c892d437f498779e349469e         0   294   168   333
# ...                                      ...       ...   ...   ...   ...
# 28532  0abd4fc2425edd5c2efb2c149e9319c6_flip         1   286    69   349
# 28533  2f4573aa154b6ee5f4ba4dc90626f5ec_flip         1   301   105   376
# 28534  2583527ca7c4a6e278fb4506ba8637ab_flip        12    77   299   198
# 28535  4e3a3b03cf00a9060ac139f57843a241_flip        12   306    68   414
# 28536  75692666e09ea0a3cbfcc4b36241c7c0_flip        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 0       170  0.618164  0.294922  0.083984  0.074219
# 1       143  0.600586  0.235352  0.080078  0.087891
# 2       206  0.651367  0.353516  0.099609  0.097656
# 3       203  0.525391  0.311523  0.277344  0.169922
# 4       210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 28532   144  0.378906  0.207031  0.123047  0.146484
# 28533   269  0.337891  0.365234  0.146484  0.320312
# 28534   366  0.730469  0.648438  0.236328  0.130859
# 28535   156  0.296875  0.218750  0.210938  0.171875
# 28536   395  0.298828  0.433594  0.271484  0.673828
#
# [28537 rows x 10 columns]

# %% [markdown]
# ## 3.rotation 90 image (counter clock)

# %%
# rotation image 만들기 (반시계 90도)

def rotation_image(image_list):
    for path in image_list:
        img = cv2.imread(path)
        (h, w) = img.shape[:2]
        (cX, cY) = (w/2, h/2)
        M = cv2.getRotationMatrix2D((cX,cY), 90, 1.0)
        rotated_img = cv2.warpAffine(img, M, (w,h))
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f'/content/aug_image/{img_name}'+'_rotated.png', rotated_img)

rotation_image(image_list)

# %%
# 바운딩박스 좌표변환.
import math 

def cossin(angle):
  cos = math.cos(math.pi*(angle/180))
  sin = math.sin(math.pi*(angle/180))

  return cos, sin

cos, sin = cossin(90)
print(cos, sin)
# Out:
# 6.123233995736766e-17 1.0

# %%
ro_90 = less_df.copy()

# 노멀리제이션되있는 mid값들을 512를 곱해서 원래 픽셀값으로 되돌리고 계산을 해줌.
ro_90["x_mid"] = ro_90.apply(lambda row: ((row.x_mid*512*cos - row.y_mid*512*sin) + 512)/512, axis =1)
ro_90["y_mid"] = ro_90.apply(lambda row: ((row.x_mid*512*sin + row.y_mid*512*cos))/512, axis =1)
ro_90['image_id'] = ro_90['image_id'] + '_rotated'
ro_90
# Out:
#                                        image_id  class_id  xmin  ymin  xmax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_rotated         1    56    76   236
# 13055  6e4391555899c8474c4d32f42b2ba21b_rotated        12   328    93   402
# 13066  8098d1ce056318c03a3c70ccf3707945_rotated         1   235   105   350
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_rotated        12    59   260   242
# 13098  fb31baa6cb3084cb283c11ee81c32f22_rotated         1   373    88   421
# ...                                         ...       ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_rotated         1   286    69   349
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_rotated         1   301   105   376
# 26896  2583527ca7c4a6e278fb4506ba8637ab_rotated        12    77   299   198
# 26943  4e3a3b03cf00a9060ac139f57843a241_rotated        12   306    68   414
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_rotated        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 13015   389  0.545898  0.545898  0.351562  0.611328
# 13055   166  0.747070  0.747070  0.144531  0.142578
# 13066   151  0.750000  0.750000  0.224609  0.089844
# 13074   340  0.414062  0.414063  0.357422  0.156250
# 13098   133  0.784180  0.784180  0.093750  0.087891
# ...     ...       ...       ...       ...       ...
# 26853   144  0.791992  0.791992  0.123047  0.146484
# 26888   269  0.634766  0.634766  0.146484  0.320312
# 26896   366  0.350586  0.350586  0.236328  0.130859
# 26943   156  0.781250  0.781250  0.210938  0.171875
# 26988   395  0.565430  0.565430  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
aug_df = pd.concat([total_df, equ_df, clahe_df, flip_df, ro_90], axis=0).reset_index().drop('index', axis=1)
aug_df
# Out:
#                                        image_id  class_id  xmin  ymin  xmax  \
# 0              d3637a1935a905b3c326af31389cb846         0   295   132   338
# 1              321c111713c3ee5385db0effb54ff568         0   287    98   328
# 2              fb8e11c6b2886b2d41b379e0598669b9         0   308   156   359
# 3              51a8d7259a0a6deac20b7c4979a7e847         0   198   116   340
# 4              381e9c224c892d437f498779e349469e         0   294   168   333
# ...                                         ...       ...   ...   ...   ...
# 29037  0abd4fc2425edd5c2efb2c149e9319c6_rotated         1   286    69   349
# 29038  2f4573aa154b6ee5f4ba4dc90626f5ec_rotated         1   301   105   376
# 29039  2583527ca7c4a6e278fb4506ba8637ab_rotated        12    77   299   198
# 29040  4e3a3b03cf00a9060ac139f57843a241_rotated        12   306    68   414
# 29041  75692666e09ea0a3cbfcc4b36241c7c0_rotated        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 0       170  0.618164  0.294922  0.083984  0.074219
# 1       143  0.600586  0.235352  0.080078  0.087891
# 2       206  0.651367  0.353516  0.099609  0.097656
# 3       203  0.525391  0.311523  0.277344  0.169922
# 4       210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 29037   144  0.791992  0.791992  0.123047  0.146484
# 29038   269  0.634766  0.634766  0.146484  0.320312
# 29039   366  0.350586  0.350586  0.236328  0.130859
# 29040   156  0.781250  0.781250  0.210938  0.171875
# 29041   395  0.565430  0.565430  0.271484  0.673828
#
# [29042 rows x 10 columns]

# %% [markdown]
# ## 4.cutmix image

# %% [markdown]
# ### generating a batch of data

# %%
# #SAMPLE -> 우린 그럼 n_images를 4가아닌 총 images개수로 바꿔줘야겠지!
# # Create batch of 4 images

# image_batch = []
# image_batch_labels = []

# n_images = 4

# for i in range(n_images):
#     image = cv2.cvtColor(cv2.imread(image_list[i]), cv2.COLOR_BGR2RGB)
#     image_batch.append(image)
    
#     label_temp = list(np.floor(np.random.rand(1)*2.99).astype(int))[0]
#     if label_temp == 0:
#         label = [1,0,0]
#     elif label_temp == 1:
#         label = [0,1,0]
#     else: # label_temp == 2
#         label = [0,0,1]
    
#     image_batch_labels.append(label)

# # Convert image_batch to numpy array
# image_batch = np.array(image_batch)
# # Conver image_batch_labels to numpy array
# image_batch_labels = np.array(image_batch_labels)
    
# # Print labels
# print()
# print(f"Image labels: {image_batch_labels}\n")

# # Show images
# for i in range(2):
#     for j in range(2):
#         plt.subplot(2,2,2*i+j+1)
#         plt.imshow(image_batch[2*i+j])
# plt.show()
# Out:
# Image labels: [[0 1 0]
#  [1 0 0]
#  [1 0 0]
#  [0 0 1]]

# %% [markdown]
# ### generating random bounding box

# %%
def rand_bbox(size, lamb):
    W = size[0]
    H = size[1]
    cut_rat = np.sqrt(1. - lamb)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
# #SAMPLE
# # Read an image
# image = cv2.cvtColor(cv2.imread(image_list[0]), cv2.COLOR_BGR2RGB)

# # Crop a random bounding box
# lamb = 0.7
# size = image.shape
# bbox = rand_bbox(size, lamb)

# # Draw bounding box on the image
# im = image.copy()
# x1 = bbox[0]
# y1 = bbox[1]
# x2 = bbox[2]
# y2 = bbox[3]
# cv2.rectangle(im, (x1, y1), (x2, y2), (255, 0, 0), 3)
# plt.imshow(im);
# plt.title('Original image with random bounding box')
# plt.show();

# # Show cropped image
# plt.imshow(image[y1:y2, x1:x2]);
# plt.title('Cropped image')
# plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# REAL
# 우린 그럼 n_images를 4가아닌 총 images개수로 바꿔줘야겠지!
# Create batch of 4394 images

image_batch = []
image_batch_labels = []

n_images = len(image_list)
from tqdm import tqdm
for i in tqdm(range(n_images)):
    image = cv2.cvtColor(cv2.imread(image_list[i]), cv2.COLOR_BGR2RGB)
    image_batch.append(image)
    
    label_temp = list(np.floor(np.random.rand(1)*2.99).astype(int))[0]
    if label_temp == 0:
        label = [1,0,0]
    elif label_temp == 1:
        label = [0,1,0]
    else: # label_temp == 2
        label = [0,0,1]
    
    image_batch_labels.append(label)

# Convert image_batch to numpy array
image_batch = np.array(image_batch) #4394개가 들어감
# Conver image_batch_labels to numpy array
image_batch_labels = np.array(image_batch_labels) #4394개가 들어감
# Out:
# 100%|██████████| 266/266 [00:00<00:00, 282.25it/s]

# %%
def generate_cutmix_image(image_batch, image_batch_labels, beta):
    """ Generate a CutMix augmented image from a batch 
    Args:
        - image_batch: a batch of input images
        - image_batch_labels: labels corresponding to the image batch
        - beta: a parameter of Beta distribution.
    Returns:
        - CutMix image batch, updated labels
    """
    # generate mixed sample
    lam = np.random.beta(beta, beta)
    rand_index = np.random.permutation(len(image_batch))
    target_a = image_batch_labels
    target_b = image_batch_labels[rand_index]
    bbx1, bby1, bbx2, bby2 = rand_bbox(image_batch[0].shape, lam)
    image_batch_updated = image_batch.copy()
    image_batch_updated[:, bbx1:bbx2, bby1:bby2, :] = image_batch[rand_index, bbx1:bbx2, bby1:bby2, :]
    
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (image_batch.shape[1] * image_batch.shape[2]))
    label = target_a * lam + target_b * (1. - lam)
    
    return image_batch_updated, label

# %%
image_batch_updated, image_batch_labels_updated = generate_cutmix_image(image_batch, image_batch_labels, 0.6)
for i,path in tqdm(enumerate(image_list)):
  image = image_batch_updated[i]
  img_name = path.split('/')[-1].split('.')[0]
  cv2.imwrite(f"/content/aug_image/{img_name}_cutmix.png", image)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# 266it [00:02, 88.93it/s]

# %%
def rand_bbox(size, lamb):
    W = size[0]
    H = size[1]
    cut_rat = np.sqrt(1. - lamb)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2



def make_img_batch_labels(image_list):
    image_batch = []
    image_batch_labels = []
    n_images = len(image_list)

    for i in tqdm(range(n_images)):
        image = cv2.cvtColor(cv2.imread(image_list[i]), cv2.COLOR_BGR2RGB)
        image_batch.append(image)
    
        label_temp = list(np.floor(np.random.rand(1)*2.99).astype(int))[0]
        if label_temp == 0:
            label = [1,0,0]
        elif label_temp == 1:
            label = [0,1,0]
        else: # label_temp == 2
            label = [0,0,1]
    
        image_batch_labels.append(label)

    # Convert image_batch to numpy array
    image_batch = np.array(image_batch) 
    # Conver image_batch_labels to numpy array
    image_batch_labels = np.array(image_batch_labels) 
    
    return image_batch, image_batch_labels



def generate_cutmix_image(image_batch, image_batch_labels, beta):
    """ Generate a CutMix augmented image from a batch 
    Args:
        - image_batch: a batch of input images
        - image_batch_labels: labels corresponding to the image batch
        - beta: a parameter of Beta distribution.
    Returns:
        - CutMix image batch, updated labels
    """
    # generate mixed sample
    lam = np.random.beta(beta, beta)
    rand_index = np.random.permutation(len(image_batch))
    target_a = image_batch_labels
    target_b = image_batch_labels[rand_index]
    bbx1, bby1, bbx2, bby2 = rand_bbox(image_batch[0].shape, lam)
    image_batch_updated = image_batch.copy()
    image_batch_updated[:, bbx1:bbx2, bby1:bby2, :] = image_batch[rand_index, bbx1:bbx2, bby1:bby2, :]
    
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (image_batch.shape[1] * image_batch.shape[2]))
    label = target_a * lam + target_b * (1. - lam)
    
    return image_batch_updated, label



image_batch, image_batch_labels = make_img_batch_labels(image_list)
image_batch_updated, image_batch_labels_updated = generate_cutmix_image(image_batch, image_batch_labels, 0.6)

def cutmix_image(image_list):
    for i,path in tqdm(enumerate(image_list)):
        image = image_batch_updated[i]
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f"/content/aug_image/{img_name}_cutmix.png", image)

cutmix_image(image_list)
# Out:
# 100%|██████████| 266/266 [00:00<00:00, 278.78it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# 266it [00:03, 87.63it/s]

# %%
# !rm /content/aug_image/*

# %%
cutmix_df = less_df.copy()
cutmix_df['image_id'] = cutmix_df['image_id'] + '_cutmix'
cutmix_df
# Out:
#                                       image_id  class_id  xmin  ymin  xmax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_cutmix         1    56    76   236
# 13055  6e4391555899c8474c4d32f42b2ba21b_cutmix        12   328    93   402
# 13066  8098d1ce056318c03a3c70ccf3707945_cutmix         1   235   105   350
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_cutmix        12    59   260   242
# 13098  fb31baa6cb3084cb283c11ee81c32f22_cutmix         1   373    88   421
# ...                                        ...       ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_cutmix         1   286    69   349
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_cutmix         1   301   105   376
# 26896  2583527ca7c4a6e278fb4506ba8637ab_cutmix        12    77   299   198
# 26943  4e3a3b03cf00a9060ac139f57843a241_cutmix        12   306    68   414
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_cutmix        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 13015   389  0.285156  0.454102  0.351562  0.611328
# 13055   166  0.712891  0.252930  0.144531  0.142578
# 13066   151  0.571289  0.250000  0.224609  0.089844
# 13074   340  0.293945  0.585938  0.357422  0.156250
# 13098   133  0.775391  0.215820  0.093750  0.087891
# ...     ...       ...       ...       ...       ...
# 26853   144  0.620117  0.208008  0.123047  0.146484
# 26888   269  0.661133  0.365234  0.146484  0.320312
# 26896   366  0.268555  0.649414  0.236328  0.130859
# 26943   156  0.703125  0.218750  0.210938  0.171875
# 26988   395  0.700195  0.434570  0.271484  0.673828
#
# [505 rows x 10 columns]

# %%
aug_df = pd.concat([total_df, equ_df, clahe_df, flip_df, ro_90, cutmix_df], axis=0).reset_index().drop('index', axis=1)
aug_df
# Out:
#                                       image_id  class_id  xmin  ymin  xmax  \
# 0             d3637a1935a905b3c326af31389cb846         0   295   132   338
# 1             321c111713c3ee5385db0effb54ff568         0   287    98   328
# 2             fb8e11c6b2886b2d41b379e0598669b9         0   308   156   359
# 3             51a8d7259a0a6deac20b7c4979a7e847         0   198   116   340
# 4             381e9c224c892d437f498779e349469e         0   294   168   333
# ...                                        ...       ...   ...   ...   ...
# 29542  0abd4fc2425edd5c2efb2c149e9319c6_cutmix         1   286    69   349
# 29543  2f4573aa154b6ee5f4ba4dc90626f5ec_cutmix         1   301   105   376
# 29544  2583527ca7c4a6e278fb4506ba8637ab_cutmix        12    77   299   198
# 29545  4e3a3b03cf00a9060ac139f57843a241_cutmix        12   306    68   414
# 29546  75692666e09ea0a3cbfcc4b36241c7c0_cutmix        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 0       170  0.618164  0.294922  0.083984  0.074219
# 1       143  0.600586  0.235352  0.080078  0.087891
# 2       206  0.651367  0.353516  0.099609  0.097656
# 3       203  0.525391  0.311523  0.277344  0.169922
# 4       210  0.612305  0.369141  0.076172  0.082031
# ...     ...       ...       ...       ...       ...
# 29542   144  0.620117  0.208008  0.123047  0.146484
# 29543   269  0.661133  0.365234  0.146484  0.320312
# 29544   366  0.268555  0.649414  0.236328  0.130859
# 29545   156  0.703125  0.218750  0.210938  0.171875
# 29546   395  0.700195  0.434570  0.271484  0.673828
#
# [29547 rows x 10 columns]

# %% [markdown]
# ## 5. zoomin image

# %%
def zoom_image(image_list):
    for path in image_list:
        img = cv2.imread(path)
        augment_img_zoom = iaa.Affine(scale=(1.1))
        zoom_image = augment_img_zoom.augment_image(img)
        img_name = path.split('/')[-1].split('.')[0]
        cv2.imwrite(f'/content/aug_image/{img_name}'+'_zoom.png', zoom_image)
zoom_image(image_list)

# %%
zoom_df = less_df.copy()
zoom_df['image_id'] = zoom_df['image_id'] + '_zoom'
zoom_df
# Out:
#                                     image_id  class_id  xmin  ymin  xmax  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_zoom         1    56    76   236
# 13055  6e4391555899c8474c4d32f42b2ba21b_zoom        12   328    93   402
# 13066  8098d1ce056318c03a3c70ccf3707945_zoom         1   235   105   350
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_zoom        12    59   260   242
# 13098  fb31baa6cb3084cb283c11ee81c32f22_zoom         1   373    88   421
# ...                                      ...       ...   ...   ...   ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_zoom         1   286    69   349
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_zoom         1   301   105   376
# 26896  2583527ca7c4a6e278fb4506ba8637ab_zoom        12    77   299   198
# 26943  4e3a3b03cf00a9060ac139f57843a241_zoom        12   306    68   414
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_zoom        12   289    50   428
#
#        ymax     x_mid     y_mid         w         h
# 13015   389  0.285156  0.454102  0.351562  0.611328
# 13055   166  0.712891  0.252930  0.144531  0.142578
# 13066   151  0.571289  0.250000  0.224609  0.089844
# 13074   340  0.293945  0.585938  0.357422  0.156250
# 13098   133  0.775391  0.215820  0.093750  0.087891
# ...     ...       ...       ...       ...       ...
# 26853   144  0.620117  0.208008  0.123047  0.146484
# 26888   269  0.661133  0.365234  0.146484  0.320312
# 26896   366  0.268555  0.649414  0.236328  0.130859
# 26943   156  0.703125  0.218750  0.210938  0.171875
# 26988   395  0.700195  0.434570  0.271484  0.673828
#
# [505 rows x 10 columns]

# %% [markdown]
# 바운딩 박스 좌표 변환

# %%
zoom_df["xmin"] = zoom_df.apply(lambda row: (row.x_mid*512 - (row.w*512/2)*(1.1**0.5)), axis =1)
zoom_df["ymin"] = zoom_df.apply(lambda row: (row.y_mid*512 - (row.h*512/2)*(1.1**0.5)), axis =1)
zoom_df["xmax"] = zoom_df.apply(lambda row: (row.x_mid*512 + (row.w*512/2)*(1.1**0.5)), axis =1)
zoom_df["ymax"] = zoom_df.apply(lambda row: (row.y_mid*512 + (row.h*512/2)*(1.1**0.5)), axis =1)
zoom_df
# Out:
#                                     image_id  class_id        xmin  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_zoom         1   51.607204
# 13055  6e4391555899c8474c4d32f42b2ba21b_zoom        12  326.194073
# 13066  8098d1ce056318c03a3c70ccf3707945_zoom         1  232.193491
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_zoom        12   54.533990
# 13098  fb31baa6cb3084cb283c11ee81c32f22_zoom         1  371.828588
# ...                                      ...       ...         ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_zoom         1  284.462521
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_zoom         1  299.169668
# 26896  2583527ca7c4a6e278fb4506ba8637ab_zoom        12   74.047065
# 26943  4e3a3b03cf00a9060ac139f57843a241_zoom        12  303.364322
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_zoom        12  285.607785
#
#              ymin        xmax        ymax     x_mid     y_mid         w  \
# 13015   68.361415  240.392796  396.638585  0.285156  0.454102  0.351562
# 13055   91.218477  403.805927  167.781523  0.712891  0.252930  0.144531
# 13066  103.877396  352.806509  152.122604  0.571289  0.250000  0.224609
# 13074  258.047646  246.466010  341.952354  0.293945  0.585938  0.357422
# 13098   86.901801  422.171412  134.098199  0.775391  0.215820  0.093750
# ...           ...         ...         ...       ...       ...       ...
# 26853   67.169668  350.537479  145.830332  0.620117  0.208008  0.123047
# 26888  100.997674  377.830332  273.002326  0.661133  0.365234  0.146484
# 26896  297.364904  200.952935  367.635096  0.268555  0.649414  0.236328
# 26943   65.852411  416.635678  158.147589  0.703125  0.218750  0.210938
# 26988   41.580474  431.392215  403.419526  0.700195  0.434570  0.271484
#
#               h
# 13015  0.611328
# 13055  0.142578
# 13066  0.089844
# 13074  0.156250
# 13098  0.087891
# ...         ...
# 26853  0.146484
# 26888  0.320312
# 26896  0.130859
# 26943  0.171875
# 26988  0.673828
#
# [505 rows x 10 columns]

# %%
zoom_df['w'] = (zoom_df['xmax']-zoom_df['xmin'])/512
zoom_df['h'] = (zoom_df['ymax']-zoom_df['ymin'])/512
zoom_df
# Out:
#                                     image_id  class_id        xmin  \
# 13015  80caa435b6ab5edaff4a0a758ffaec6e_zoom         1   51.607204
# 13055  6e4391555899c8474c4d32f42b2ba21b_zoom        12  326.194073
# 13066  8098d1ce056318c03a3c70ccf3707945_zoom         1  232.193491
# 13074  e3c5ff1eb0d55039f3bbc3c4875543c3_zoom        12   54.533990
# 13098  fb31baa6cb3084cb283c11ee81c32f22_zoom         1  371.828588
# ...                                      ...       ...         ...
# 26853  0abd4fc2425edd5c2efb2c149e9319c6_zoom         1  284.462521
# 26888  2f4573aa154b6ee5f4ba4dc90626f5ec_zoom         1  299.169668
# 26896  2583527ca7c4a6e278fb4506ba8637ab_zoom        12   74.047065
# 26943  4e3a3b03cf00a9060ac139f57843a241_zoom        12  303.364322
# 26988  75692666e09ea0a3cbfcc4b36241c7c0_zoom        12  285.607785
#
#              ymin        xmax        ymax     x_mid     y_mid         w  \
# 13015   68.361415  240.392796  396.638585  0.285156  0.454102  0.368722
# 13055   91.218477  403.805927  167.781523  0.712891  0.252930  0.151586
# 13066  103.877396  352.806509  152.122604  0.571289  0.250000  0.235572
# 13074  258.047646  246.466010  341.952354  0.293945  0.585938  0.374867
# 13098   86.901801  422.171412  134.098199  0.775391  0.215820  0.098326
# ...           ...         ...         ...       ...       ...       ...
# 26853   67.169668  350.537479  145.830332  0.620117  0.208008  0.129053
# 26888  100.997674  377.830332  273.002326  0.661133  0.365234  0.153634
# 26896  297.364904  200.952935  367.635096  0.268555  0.649414  0.247863
# 26943   65.852411  416.635678  158.147589  0.703125  0.218750  0.221233
# 26988   41.580474  431.392215  403.419526  0.700195  0.434570  0.284735
#
#               h
# 13015  0.641166
# 13055  0.149537
# 13066  0.094229
# 13074  0.163876
# 13098  0.092180
# ...         ...
# 26853  0.153634
# 26888  0.335947
# 26896  0.137246
# 26943  0.180264
# 26988  0.706717
#
# [505 rows x 10 columns]

# %%
aug_df = pd.concat([total_df, equ_df, clahe_df, flip_df, ro_90, cutmix_df, zoom_df], axis=0).reset_index().drop('index', axis=1)
aug_df
# Out:
#                                     image_id  class_id        xmin  \
# 0           d3637a1935a905b3c326af31389cb846         0  295.000000
# 1           321c111713c3ee5385db0effb54ff568         0  287.000000
# 2           fb8e11c6b2886b2d41b379e0598669b9         0  308.000000
# 3           51a8d7259a0a6deac20b7c4979a7e847         0  198.000000
# 4           381e9c224c892d437f498779e349469e         0  294.000000
# ...                                      ...       ...         ...
# 30047  0abd4fc2425edd5c2efb2c149e9319c6_zoom         1  284.462521
# 30048  2f4573aa154b6ee5f4ba4dc90626f5ec_zoom         1  299.169668
# 30049  2583527ca7c4a6e278fb4506ba8637ab_zoom        12   74.047065
# 30050  4e3a3b03cf00a9060ac139f57843a241_zoom        12  303.364322
# 30051  75692666e09ea0a3cbfcc4b36241c7c0_zoom        12  285.607785
#
#              ymin        xmax        ymax     x_mid     y_mid         w  \
# 0      132.000000  338.000000  170.000000  0.618164  0.294922  0.083984
# 1       98.000000  328.000000  143.000000  0.600586  0.235352  0.080078
# 2      156.000000  359.000000  206.000000  0.651367  0.353516  0.099609
# 3      116.000000  340.000000  203.000000  0.525391  0.311523  0.277344
# 4      168.000000  333.000000  210.000000  0.612305  0.369141  0.076172
# ...           ...         ...         ...       ...       ...       ...
# 30047   67.169668  350.537479  145.830332  0.620117  0.208008  0.129053
# 30048  100.997674  377.830332  273.002326  0.661133  0.365234  0.153634
# 30049  297.364904  200.952935  367.635096  0.268555  0.649414  0.247863
# 30050   65.852411  416.635678  158.147589  0.703125  0.218750  0.221233
# 30051   41.580474  431.392215  403.419526  0.700195  0.434570  0.284735
#
#               h
# 0      0.074219
# 1      0.087891
# 2      0.097656
# 3      0.169922
# 4      0.082031
# ...         ...
# 30047  0.153634
# 30048  0.335947
# 30049  0.137246
# 30050  0.180264
# 30051  0.706717
#
# [30052 rows x 10 columns]

# %% [markdown]
# # Task3. 라벨 텍스트 만들기

# %% [markdown]
# ## 증강한 이미지 라벨 텍스트 생성

# %%
# 1,12번 이미지 경로 리스트 
input_path = "/content/aug_image/*.png"
aug_image_list = [f for f in glob.glob(input_path)]
len(aug_image_list)
# Out:
# 1596

# %%
aug_df = pd.concat([equ_df, clahe_df, flip_df, ro_90, cutmix_df, zoom_df], axis=0).reset_index().drop('index', axis=1)
aug_df

# %%
aug_img_name = aug_df.image_id.unique().tolist()

# %%
aug_xywh_df = aug_df.copy()
aug_xywh_df = aug_xywh_df[['image_id', 'class_id', 'x_mid', 'y_mid', 'w', 'h']]
aug_xywh_df

# %%
# !mkdir /content/aug_label
path = '/content/aug_label/'
for filename in aug_img_name:
    id_list = aug_df.index[aug_df['image_id'] == filename].tolist()
    for idx in id_list:
        xywh_list = aug_xywh_df.loc[idx][1:].tolist()
        with open(path+filename+'.txt', 'a') as f:
            for xywh in xywh_list:
                f.write(str(xywh) + '\t')
            f.write('\n')

# %% [markdown]
# png -> jpg

# %%
len(os.listdir('/content/augment_image')), len(os.listdir('/content/aug_label'))

# %%
# !mkdir /content/augment_image

# %%
input_path = "/content/aug_image/*.png"
file_list = [f for f in glob.glob(input_path)]
for i in range(0,len(file_list)):
    text = file_list[i].split('.')[-2]
    im = Image.open(text+".png").convert('RGB')
    text_1 = text.split('/')[-1]
    im.save('/content/augment_image/'+ text_1+'.jpg', 'jpeg')

# %%
# !zip -r augment_image.zip /content/augment_image/*
# !zip -r aug_label.zip /content/aug_label/*


# !mv augment_image.zip /content/drive/MyDrive
# !mv aug_label.zip /content/drive/MyDrive

# %% [markdown]
# ## 다운샘플링 이미지 라벨 텍스트 생성

# %%
# %mv /content/aug_image/* /content/vinbigdata/train/ 
# !rm -r /content/aug_image/

# %%
augment_df = pd.concat([total_df, equ_df, clahe_df, flip_df, ro_90, cutmix_df, zoom_df], axis=0).reset_index().drop('index', axis=1)
augment_df['img_path'] = '/content/vinbigdata/train/' + augment_df['image_id'] + '.png'
augment_df
# Out:
#                                     image_id  class_id        xmin  \
# 0           d3637a1935a905b3c326af31389cb846         0  295.000000
# 1           321c111713c3ee5385db0effb54ff568         0  287.000000
# 2           fb8e11c6b2886b2d41b379e0598669b9         0  308.000000
# 3           51a8d7259a0a6deac20b7c4979a7e847         0  198.000000
# 4           381e9c224c892d437f498779e349469e         0  294.000000
# ...                                      ...       ...         ...
# 30047  0abd4fc2425edd5c2efb2c149e9319c6_zoom         1  284.462521
# 30048  2f4573aa154b6ee5f4ba4dc90626f5ec_zoom         1  299.169668
# 30049  2583527ca7c4a6e278fb4506ba8637ab_zoom        12   74.047065
# 30050  4e3a3b03cf00a9060ac139f57843a241_zoom        12  303.364322
# 30051  75692666e09ea0a3cbfcc4b36241c7c0_zoom        12  285.607785
#
#              ymin        xmax        ymax     x_mid     y_mid         w  \
# 0      132.000000  338.000000  170.000000  0.618164  0.294922  0.083984
# 1       98.000000  328.000000  143.000000  0.600586  0.235352  0.080078
# 2      156.000000  359.000000  206.000000  0.651367  0.353516  0.099609
# 3      116.000000  340.000000  203.000000  0.525391  0.311523  0.277344
# 4      168.000000  333.000000  210.000000  0.612305  0.369141  0.076172
# ...           ...         ...         ...       ...       ...       ...
# 30047   67.169668  350.537479  145.830332  0.620117  0.208008  0.129053
# 30048  100.997674  377.830332  273.002326  0.661133  0.365234  0.153634
# 30049  297.364904  200.952935  367.635096  0.268555  0.649414  0.247863
# 30050   65.852411  416.635678  158.147589  0.703125  0.218750  0.221233
# 30051   41.580474  431.392215  403.419526  0.700195  0.434570  0.284735
#
#               h                                           img_path
# 0      0.074219  /content/vinbigdata/train/d3637a1935a905b3c326...
# 1      0.087891  /content/vinbigdata/train/321c111713c3ee5385db...
# 2      0.097656  /content/vinbigdata/train/fb8e11c6b2886b2d41b3...
# 3      0.169922  /content/vinbigdata/train/51a8d7259a0a6deac20b...
# 4      0.082031  /content/vinbigdata/train/381e9c224c892d437f49...
# ...         ...                                                ...
# 30047  0.153634  /content/vinbigdata/train/0abd4fc2425edd5c2efb...
# 30048  0.335947  /content/vinbigdata/train/2f4573aa154b6ee5f4ba...
# 30049  0.137246  /content/vinbigdata/train/2583527ca7c4a6e278fb...
# 30050  0.180264  /content/vinbigdata/train/4e3a3b03cf00a9060ac1...
# 30051  0.706717  /content/vinbigdata/train/75692666e09ea0a3cbfc...
#
# [30052 rows x 11 columns]

# %%
path_list = augment_df.img_path.tolist()
path_list

# %%
# !mkdir /content/train_image/

# %%
for i in range(0,len(path_list)):
    text = path_list[i].split('.')[-2]
    im = Image.open(text+".png").convert('RGB')
    text_1 = text.split('/')[-1]
    im.save('/content/train_image/'+ text_1+'.jpg', 'jpeg')

# %%
augment_df.class_id.value_counts()

# %%
aug_img_name = augment_df.image_id.unique().tolist()
len(aug_img_name)

# %%
aug_df = augment_df.copy()
aug_df = aug_df[['image_id', 'class_id', 'x_mid', 'y_mid', 'w', 'h']]
aug_df

# %%
# !mkdir /content/train_label
path = '/content/train_label/'
for filename in aug_img_name:
    id_list = aug_df.index[aug_df['image_id'] == filename].tolist()
    for idx in id_list:
        xywh_list = aug_df.loc[idx][1:].tolist()
        with open(path+filename+'.txt', 'a') as f:
            for xywh in xywh_list:
                f.write(str(xywh) + '\t')
            f.write('\n')

# %%
# !zip -r train_image.zip /content/train_image/*
# !zip -r train_label.zip /content/train_label/*


# !mv train_image.zip /content/drive/MyDrive
# !mv train_label.zip /content/drive/MyDrive

# %%
count_df = pd.DataFrame(augment_df.class_id.value_counts()) # 평균값은 2578
count_df.plot.bar(figsize=(10,5), rot=0)
